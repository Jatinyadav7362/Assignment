# %% [markdown]
# **Movie Analysis**

# %%
import pandas  as pd

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Jatin Yadav\Desktop\Assignment\Dataset of assignments\IMDB-Movie-Data.csv")

# %%
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
df.corr()
# Out:
# C:\Users\Jatin Yadav\AppData\Local\Temp\ipykernel_17560\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.271592 -0.126790           0.267953  0.217654  0.639661
# Metascore          -0.191869 -0.079305           0.211978  0.631897  0.325684
#
# ...

# %% [markdown]
# **Cleaning the data**

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
a=df['Revenue (Millions)'].median()
b=df['Metascore'].median()

# %%
df['Revenue (Millions)'].fillna(a,inplace=True)
df['Metascore'].fillna(b,inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
#2
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#3
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  1000 non-null   float64
#  11  Metascore           1000 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
#4
df.isnull().sum()
#using either dropna or fillna
# Out:
# Rank                  0
# Title                 0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
#5
df.loc[:,['Description','Rating']]
# Out:
#                                            Description  Rating
# 0    A group of intergalactic criminals are forced ...     8.1
# 1    Following clues to the origin of mankind, a te...     7.0
# 2    Three girls are kidnapped by a man with a diag...     7.3
# 3    In a city of humanoid animals, a hustling thea...     7.2
# 4    A secret government agency recruits some of th...     6.2
# ..                                                 ...     ...
# 995  A tight-knit team of rising investigators, alo...     6.2
# 996  Three American college students studying abroa...     5.5
# 997  Romantic sparks occur between two dance studen...     6.2
# 998  A pair of friends embark on a mission to reuni...     5.6
# 999  A stuffy businessman finds himself trapped ins...     5.3
#
# [1000 rows x 2 columns]

# %%
#6
df['Runtime (Minutes)'].mean()
# Out:
# 113.172

# %%
list(df.columns)
# Out:
# ['Rank',
#  'Title',
#  'Genre',
#  'Description',
#  'Director',
#  'Actors',
#  'Year',
#  'Runtime (Minutes)',
#  'Rating',
#  'Votes',
#  'Revenue (Millions)',
#  'Metascore']

# %%
#7
genre_counts=df['Genre'].value_counts()

# %%
#9
x=df.Genre
fig=plt.figure()
genre_counts.plot(kind='bar',figsize=(10,10))
plt.xlabel("Genre")
plt.ylabel('Number of movies in that genre')
plt.title("number of movies in each genre")



plt.tight_layout()
plt.show()

# %%
#8
df['Director'].value_counts(sort=True).head(5)
# Out:
# Ridley Scott          8
# David Yates           6
# M. Night Shyamalan    6
# Paul W.S. Anderson    6
# Michael Bay           6
# Name: Director, dtype: int64

# %%
#9
year_counts=df['Year'].value_counts()
x=df['Year']
fig=plt.figure()
year_counts.plot(kind='line')

plt.xlabel("Year")
plt.ylabel('Number of movies in that year')
plt.title("number of movies in each year")
# Out:
# Text(0.5, 1.0, 'number of movies in each year')

# %%
#10
num_bins = 10

plt.hist(df['Runtime (Minutes)'], bins=num_bins, edgecolor='k', alpha=0.7)

plt.xlabel('Movie Runtimes')
plt.ylabel('Frequency')
plt.title('Distribution of Movie Runtimes')

# Show the plot
plt.show()

# %%
#11
plt.hist(df['Rating'],bins=10,edgecolor='k')
plt.xlabel('Movie Ratings')
plt.ylabel('Frequency')
plt.title('Distribution of Movie Ratings')
plt.show()

# %%
#12
df['Runtime (Minutes)'].corr(df['Runtime (Minutes)'])
# Out:
# 0.9999999999999998

# %%
#13
df['Actors'].value_counts(sort=True).head(3)
# Out:
# Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody Harrelson    2
# Daniel Radcliffe, Emma Watson, Rupert Grint, Michael Gambon            2
# Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese Gibson                   2
# Name: Actors, dtype: int64

# %%
#14
df['Revenue (Millions)'].corr(df['Rating'])
# Out:
# 0.2184478602329313

# %%
#15
plt.scatter(df['Rating'],df['Revenue (Millions)'])
plt.xlabel("Ratings")
plt.ylabel("Revenue (Millions)")
plt.title("Relationship between ratings and revenue")
plt.show()

# %%
#16 #17 #18
# Data not available

# %%
#19
from wordcloud import WordCloud



# Combine movie titles into a single string
titles = " ".join(df['Title'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=800, background_color='white', max_words=200).generate(titles)

# Plot the WordCloud image
plt.figure(figsize=(8, 8), facecolor='black')
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad=0)

plt.show()

# %%
#20
average_ratings = df.groupby('Year')['Rating'].mean()
plt.figure(figsize=(10, 6))
plt.plot(average_ratings.index, average_ratings.values, marker='o')
plt.title('Average Movie Ratings Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.grid(True)
plt.show()

# %%
#21
(df['Rating']).corr(df['Year'])
#so the rating decreased with each year
# Out:
# -0.211218756603513

# %%
#22
df.value_counts(subset=['Actors','Director'],sort=True).head(3)
# Out:
# Actors                                                               Director
# Shia LaBeouf, Megan Fox, Josh Duhamel, Tyrese Gibson                 Michael Bay         2
# Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody Harrelson  Francis Lawrence    2
# Daniel Radcliffe, Emma Watson, Rupert Grint, Michael Gambon          David Yates         2
# dtype: int64

# %%
#23
print("correlation of year and runtime is: ",df['Year'].corr(df['Runtime (Minutes)']))

plt.scatter(df['Year'],df['Runtime (Minutes)'])
plt.xlabel("Years")
plt.ylabel("Runtime")
plt.show()
plt.show()
# Out:
# correlation of year and runtime is:  -0.16489980903636647

# %%
#24
trend=df['Genre'].value_counts(sort=True)
plt.bar(trend.index,trend.values)

plt.show()

# %%
#28
print("correlation of rating and votes is: ",df['Rating'].corr(df['Votes']))
plt.figure(figsize=(10, 6))
plt.scatter(df['Rating'],df['Votes'])
plt.ylabel('Number of Votes')
plt.xlabel('Movie Rating')
plt.title('Relationship between Number of Votes and Movie Rating')
plt.show()
# Out:
# correlation of rating and votes is:  0.5115373197657556

# %%
#28
print("correlation of rating an votes is: ",df['Rating'].corr(df['Votes']))
plt.figure(figsize=(10, 6))
plt.scatter(df['Rating'],df['Votes'])
plt.ylabel('Number of Votes')
plt.xlabel('Movie Rating')
plt.title('Relationship between Number of Votes and Movie Rating')
plt.show()
# Out:
# correlation of rating an votes is:  0.5115373197657556

# %%
#24
plt.figure(figsize=(100,99))
plt.bar(df['Genre'],df['Rating'])
plt.show()

# %%
#25
#identifying outliers using boxplot
plt.figure(figsize=(10,8))
plt.boxplot(df['Runtime (Minutes)'])
plt.grid()
plt.show()

# %%
#Identifying outliers using iqr 
Q1=df['Runtime (Minutes)'].quantile(0.25)
Q3=df['Runtime (Minutes)'].quantile(0.75)

# %%
Q1,Q3
# Out:
# (100.0, 123.0)

# %%
IQR=Q3-Q1

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (65.5, 157.5)

# %%
outliers=df[(df['Runtime (Minutes)'] > lower_limit) & (df['Runtime (Minutes)'] < upper_limit)]

# %%
#Handling the outliers
filtered_data=df[(df['Runtime (Minutes)'] >= lower_limit) & (df['Runtime (Minutes)'] <= upper_limit)]

# %%
filtered_data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
plt.figure(figsize=(10,8))
plt.boxplot(filtered_data['Runtime (Minutes)'])
plt.grid()
plt.show()
